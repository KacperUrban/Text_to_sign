# %% [markdown]
# ## Load require libraries

# %%
import pandas as pd
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
os.environ["NEPTUNE_API_TOKEN"] = "eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiI3MTRhNjcwNy1iMzc2LTQwNTUtOGRjYy03ODI4OGQzNjkxNTEifQ=="
from datasets import Dataset, DatasetDict
from transformers import DataCollatorForSeq2Seq
from transformers import AutoTokenizer, TFAutoModelForSeq2SeqLM
from transformers import pipeline
from tf_keras.callbacks import EarlyStopping
from tf_keras.optimizers import Adam
import neptune
from neptune.integrations.tensorflow_keras import NeptuneCallback
from custom_bleu import CustomBleu

# %% [markdown]
# ## Check if model is working properly

# %%
model = TFAutoModelForSeq2SeqLM.from_pretrained("model/model")
tokenizer = AutoTokenizer.from_pretrained("model/tokenizer/")
# Out:
# WARNING:tensorflow:From c:\Users\48663\Desktop\Projects\Text_to_Sign\ttsvenv\lib\site-packages\tf_keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# All model checkpoint layers were used when initializing TFMarianMTModel.
#
# All the layers of TFMarianMTModel were initialized from the model checkpoint at model/model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFMarianMTModel for predictions without further training.

# %%
translation = pipeline("translation", model=model, tokenizer=tokenizer)
translation("Lubie jesc jablka!")
# Out:
# [{'translation_text': 'I like eating apple!'}]

# %% [markdown]
# ## Data preparation

# %% [markdown]
# ### Load data

# %%
data = pd.read_csv('data/All_data.csv')
print(data[0:10])
# Out:
#                                                   pl  \
# 0  Mój dziadek jest inwalidą wojennym i otrzymuję...
# 1                Czy ma Pan legitymację kombatancką?
# 2                  Mam wezwanie na komisje lekarską.
# 3                    Moja mama otrzymuje rentę krus.
# 4               Czy ma Pani ukończony kurs rolniczy?
# 5                Czy ma Pan ukończony kurs rolniczy?
# 6                Ja pracuję na gospodarstwie rolnym.
# 7                           Mój brat jest kawalerem.
# 8     Ja płacę duży rachunek za gaz i elektryczność.
# 9         W jakim sklepie można zrobić tanie zakupy?
#
#                                           mig
# 0   Mój dziadek inwalida wojna renta zus mieć
# 1               Ty legitymacja kombatant mieć
# 2           Ja komisja lekarska wezwanie mieć
# 3                   Moja mama renta krus mieć
# 4                       Ty kurs rolniczy mieć
# 5                       Ty kurs rolniczy mieć
# 6            Ja gospodarstwo rolne praca mieć
# 7                        Mój brat kawaler być
# 8  Ja gaz elektrycznosc rachunek drogo płacić
# 9                    Sklep gdzie zakupy tanio

# %% [markdown]
# ### Create a dataset

# %%
raw_dataset_list = []
for i in range(0, len(data)):
    raw_dataset_list.append({'translation' : {'pl' : data['pl'][i], 'mig' : data['mig'][i]}})

raw_dataset = Dataset.from_list(raw_dataset_list)
raw_dataset
# Out:
# Dataset({
#     features: ['translation'],
#     num_rows: 1211
# })

# %% [markdown]
# ### Split data into train and test dataset

# %%
train_test = raw_dataset.train_test_split(test_size=0.2, seed=42)
valid_test = train_test['test'].train_test_split(test_size=0.5, seed=42)
train_test_dataset = DatasetDict({
    'train': train_test['train'],
    'valid': valid_test['train'],
    'test': valid_test['test']})
train_test_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['translation'],
#         num_rows: 847
#     })
#     valid: Dataset({
#         features: ['translation'],
#         num_rows: 182
#     })
#     test: Dataset({
#         features: ['translation'],
#         num_rows: 182
#     })
# })

# %% [markdown]
# ### Create preprocessing function for our data

# %%
max_input_length = 32
max_target_length = 32
source_lang = "pl"
target_lang = "mig"


def preprocess_function(examples):
    inputs = [ex[source_lang] for ex in examples["translation"]]
    targets = [ex[target_lang] for ex in examples["translation"]]
    model_inputs = tokenizer(inputs, text_target=targets)
    return model_inputs

# %% [markdown]
# ### Map preprocess function on our dataset

# %%
tokenized_dataset = train_test_dataset.map(preprocess_function, batched=True)
# Out:
# Map: 100%|██████████| 847/847 [00:00<00:00, 7177.89 examples/s]
# Map: 100%|██████████| 182/182 [00:00<00:00, 6748.80 examples/s]
# Map: 100%|██████████| 182/182 [00:00<00:00, 6268.17 examples/s]

# %%
batch_size = 8

data_collator = DataCollatorForSeq2Seq(tokenizer, model=model, return_tensors="tf")
train_dataset = model.prepare_tf_dataset(
    tokenized_dataset["train"],
    batch_size=batch_size,
    shuffle=True,
    collate_fn=data_collator,
)

valid_dataset = model.prepare_tf_dataset(
    tokenized_dataset["valid"],
    batch_size=batch_size,
    shuffle=False,
    collate_fn=data_collator,
)

# %% [markdown]
# ## Model preparation

# %%
model.summary()
# Out:
# Model: "tf_marian_mt_model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  model (TFMarianMainLayer)   multiple                  77138944
#
#  final_logits_bias (BiasLay  multiple                  63430
#  er)
#
# =================================================================
# Total params: 77202374 (294.50 MB)
# Trainable params: 77138944 (294.26 MB)
# Non-trainable params: 63430 (247.77 KB)
# _________________________________________________________________

# %%
model.model.encoder.trainable = False
model.model.encoder.get_config()
# Out:
# {'name': 'encoder',
#  'trainable': False,
#  'dtype': 'float32',
#  'config': {'vocab_size': 63430,
#   'decoder_vocab_size': 63430,
#   'max_position_embeddings': 512,
#   'd_model': 512,
#   'encoder_ffn_dim': 2048,
#   'encoder_layers': 6,
#   'encoder_attention_heads': 8,
#   'decoder_ffn_dim': 2048,
#   'decoder_layers': 6,
#   'decoder_attention_heads': 8,
#   'dropout': 0.1,
#   'attention_dropout': 0.0,
#   'activation_dropout': 0.0,
#   'activation_function': 'swish',
#   'init_std': 0.02,
#   'encoder_layerdrop': 0.0,
#   'decoder_layerdrop': 0.0,
#   'use_cache': True,
#   'num_hidden_layers': 6,
#   'scale_embedding': True,
#   'share_encoder_decoder_embeddings': True,
#   'return_dict': True,
#   'output_hidden_states': False,
#   'output_attentions': False,
#   'torchscript': False,
#   'torch_dtype': None,
#   'use_bfloat16': False,
#   'tf_legacy_loss': False,
#   'pruned_heads': {},
#   'tie_word_embeddings': True,
#   'chunk_size_feed_forward': 0,
#   'is_encoder_decoder': True,
#   'is_decoder': False,
#   'cross_attention_hidden_size': None,
#   'add_cross_attention': False,
#   'tie_encoder_decoder': False,
#   'max_length': 512,
#   'min_length': 0,
#   'do_sample': False,
#   'early_stopping': False,
#   'num_beams': 6,
#   'num_beam_groups': 1,
#   'diversity_penalty': 0.0,
#   'temperature': 1.0,
#   'top_k': 50,
#   'top_p': 1.0,
#   'typical_p': 1.0,
#   'repetition_penalty': 1.0,
#   'length_penalty': 1.0,
#   'no_repeat_ngram_size': 0,
#   'encoder_no_repeat_ngram_size': 0,
#   'bad_words_ids': [[63429]],
#   'num_return_sequences': 1,
#   'output_scores': False,
#   'return_dict_in_generate': False,
#   'forced_bos_token_id': None,
#   'forced_eos_token_id': 0,
#   'remove_invalid_values': False,
#   'exponential_decay_length_penalty': None,
#   'suppress_tokens': None,
#   'begin_suppress_tokens': None,
#   'architectures': ['MarianMTModel'],
#   'finetuning_task': None,
#   'id2label': {0: 'LABEL_0', 1: 'LABEL_1', 2: 'LABEL_2'},
#   'label2id': {'LABEL_0': 0, 'LABEL_1': 1, 'LABEL_2': 2},
#   'tokenizer_class': None,
#   'prefix': None,
#   'bos_token_id': 0,
#   'pad_token_id': 63429,
#   'eos_token_id': 0,
#   'sep_token_id': None,
#   'decoder_start_token_id': 63429,
#   'task_specific_params': None,
#   'problem_type': None,
#   '_name_or_path': 'model/model',
#   'transformers_version': '4.39.3',
#   '_num_labels': 3,
#   'add_bias_logits': False,
#   'add_final_layer_norm': False,
#   'classif_dropout': 0.0,
#   'classifier_dropout': 0.0,
#   'model_type': 'marian',
#   'normalize_before': False,
#   'normalize_embedding': False,
#   'static_position_embeddings': True}}

# %%
model.model.decoder.get_config()
# Out:
# {'name': 'decoder',
#  'trainable': True,
#  'dtype': 'float32',
#  'config': {'vocab_size': 63430,
#   'decoder_vocab_size': 63430,
#   'max_position_embeddings': 512,
#   'd_model': 512,
#   'encoder_ffn_dim': 2048,
#   'encoder_layers': 6,
#   'encoder_attention_heads': 8,
#   'decoder_ffn_dim': 2048,
#   'decoder_layers': 6,
#   'decoder_attention_heads': 8,
#   'dropout': 0.1,
#   'attention_dropout': 0.0,
#   'activation_dropout': 0.0,
#   'activation_function': 'swish',
#   'init_std': 0.02,
#   'encoder_layerdrop': 0.0,
#   'decoder_layerdrop': 0.0,
#   'use_cache': True,
#   'num_hidden_layers': 6,
#   'scale_embedding': True,
#   'share_encoder_decoder_embeddings': True,
#   'return_dict': True,
#   'output_hidden_states': False,
#   'output_attentions': False,
#   'torchscript': False,
#   'torch_dtype': None,
#   'use_bfloat16': False,
#   'tf_legacy_loss': False,
#   'pruned_heads': {},
#   'tie_word_embeddings': True,
#   'chunk_size_feed_forward': 0,
#   'is_encoder_decoder': True,
#   'is_decoder': False,
#   'cross_attention_hidden_size': None,
#   'add_cross_attention': False,
#   'tie_encoder_decoder': False,
#   'max_length': 512,
#   'min_length': 0,
#   'do_sample': False,
#   'early_stopping': False,
#   'num_beams': 6,
#   'num_beam_groups': 1,
#   'diversity_penalty': 0.0,
#   'temperature': 1.0,
#   'top_k': 50,
#   'top_p': 1.0,
#   'typical_p': 1.0,
#   'repetition_penalty': 1.0,
#   'length_penalty': 1.0,
#   'no_repeat_ngram_size': 0,
#   'encoder_no_repeat_ngram_size': 0,
#   'bad_words_ids': [[63429]],
#   'num_return_sequences': 1,
#   'output_scores': False,
#   'return_dict_in_generate': False,
#   'forced_bos_token_id': None,
#   'forced_eos_token_id': 0,
#   'remove_invalid_values': False,
#   'exponential_decay_length_penalty': None,
#   'suppress_tokens': None,
#   'begin_suppress_tokens': None,
#   'architectures': ['MarianMTModel'],
#   'finetuning_task': None,
#   'id2label': {0: 'LABEL_0', 1: 'LABEL_1', 2: 'LABEL_2'},
#   'label2id': {'LABEL_0': 0, 'LABEL_1': 1, 'LABEL_2': 2},
#   'tokenizer_class': None,
#   'prefix': None,
#   'bos_token_id': 0,
#   'pad_token_id': 63429,
#   'eos_token_id': 0,
#   'sep_token_id': None,
#   'decoder_start_token_id': 63429,
#   'task_specific_params': None,
#   'problem_type': None,
#   '_name_or_path': 'model/model',
#   'transformers_version': '4.39.3',
#   '_num_labels': 3,
#   'add_bias_logits': False,
#   'add_final_layer_norm': False,
#   'classif_dropout': 0.0,
#   'classifier_dropout': 0.0,
#   'model_type': 'marian',
#   'normalize_before': False,
#   'normalize_embedding': False,
#   'static_position_embeddings': True}}

# %%
model.summary()
# Out:
# Model: "tf_marian_mt_model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  model (TFMarianMainLayer)   multiple                  77138944
#
#  final_logits_bias (BiasLay  multiple                  63430
#  er)
#
# =================================================================
# Total params: 77202374 (294.50 MB)
# Trainable params: 25486336 (97.22 MB)
# Non-trainable params: 51716038 (197.28 MB)
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(0.00005), metrics=["accuracy"], run_eagerly=True)

# %% [markdown]
# ## Model training

# %% [markdown]
# ### Initialize Neptune

# %%
run = neptune.init_run(
    project="kacperurban/pl-mig-translation",
    tags='test',
)

neptune_callback = NeptuneCallback(run=run)

# %% [markdown]
# ### Training

# %%
early_stopping_callback = EarlyStopping(monitor='loss', patience=5)
model.fit(train_dataset, epochs=100, validation_data=valid_dataset, callbacks=[early_stopping_callback])
# Out:
# Epoch 1/100
# 105/105 [==============================] - 387s 4s/step - loss: 3.3964 - accuracy: 0.2453 - val_loss: 2.3314 - val_accuracy: 0.3451
# Epoch 2/100
# 105/105 [==============================] - 393s 4s/step - loss: 2.0933 - accuracy: 0.3776 - val_loss: 1.8732 - val_accuracy: 0.4028
# Epoch 3/100
# 105/105 [==============================] - 400s 4s/step - loss: 1.5396 - accuracy: 0.4422 - val_loss: 1.6787 - val_accuracy: 0.4267
# Epoch 4/100
# 105/105 [==============================] - 389s 4s/step - loss: 1.1598 - accuracy: 0.4875 - val_loss: 1.5376 - val_accuracy: 0.4528
# Epoch 5/100
# 105/105 [==============================] - 381s 4s/step - loss: 0.9120 - accuracy: 0.5320 - val_loss: 1.4695 - val_accuracy: 0.4528
# Epoch 6/100
# 105/105 [==============================] - 391s 4s/step - loss: 0.7186 - accuracy: 0.5491 - val_loss: 1.4254 - val_accuracy: 0.4646
# Epoch 7/100
# 105/105 [==============================] - 386s 4s/step - loss: 0.5807 - accuracy: 0.5754 - val_loss: 1.4296 - val_accuracy: 0.4665
# Epoch 8/100
# 105/105 [==============================] - 395s 4s/step - loss: 0.4671 - accuracy: 0.5837 - val_loss: 1.4039 - val_accuracy: 0.4774
# Epoch 9/100
# 105/105 [==============================] - 389s 4s/step - loss: 0.3924 - accuracy: 0.5903 - val_loss: 1.3888 - val_accuracy: 0.4790
# Epoch 10/100
# 105/105 [==============================] - 390s 4s/step - loss: 0.3312 - accuracy: 0.6136 - val_loss: 1.3985 - val_accuracy: 0.4815
# Epoch 11/100
# 105/105 [==============================] - 387s 4s/step - loss: 0.2781 - accuracy: 0.6136 - val_loss: 1.4102 - val_accuracy: 0.4799
# Epoch 12/100
# 105/105 [==============================] - 392s 4s/step - loss: 0.2488 - accuracy: 0.6170 - val_loss: 1.4476 - val_accuracy: 0.4774
# Epoch 13/100
# 105/105 [==============================] - 397s 4s/step - loss: 0.2237 - accuracy: 0.6221 - val_loss: 1.4204 - val_accuracy: 0.4837
# Epoch 14/100
# 105/105 [==============================] - 436s 4s/step - loss: 0.2009 - accuracy: 0.6290 - val_loss: 1.4500 - val_accuracy: 0.4796
# Epoch 15/100
# 105/105 [==============================] - 515s 5s/step - loss: 0.1865 - accuracy: 0.6306 - val_loss: 1.4341 - val_accuracy: 0.4866
# Epoch 16/100
# 105/105 [==============================] - 487s 5s/step - loss: 0.1718 - accuracy: 0.6359 - val_loss: 1.4857 - val_accuracy: 0.4825
# Epoch 17/100
# 105/105 [==============================] - 488s 5s/step - loss: 0.1545 - accuracy: 0.6365 - val_loss: 1.4787 - val_accuracy: 0.4786
# Epoch 18/100
# 105/105 [==============================] - 567s 5s/step - loss: 0.1495 - accuracy: 0.6340 - val_loss: 1.5149 - val_accuracy: 0.4847
# Epoch 19/100
# 105/105 [==============================] - 561s 5s/step - loss: 0.1452 - accuracy: 0.6366 - val_loss: 1.5075 - val_accuracy: 0.4857
# Epoch 20/100
# 105/105 [==============================] - 559s 5s/step - loss: 0.1388 - accuracy: 0.6393 - val_loss: 1.5105 - val_accuracy: 0.4841
# Epoch 21/100
# 105/105 [==============================] - 547s 5s/step - loss: 0.1312 - accuracy: 0.6349 - val_loss: 1.5269 - val_accuracy: 0.4793
# Epoch 22/100
# 105/105 [==============================] - 478s 5s/step - loss: 0.1273 - accuracy: 0.6378 - val_loss: 1.5070 - val_accuracy: 0.4831
# Epoch 23/100
# 105/105 [==============================] - 482s 5s/step - loss: 0.1249 - accuracy: 0.6355 - val_loss: 1.5370 - val_accuracy: 0.4825
# Epoch 24/100
# 105/105 [==============================] - 540s 5s/step - loss: 0.1222 - accuracy: 0.6478 - val_loss: 1.5226 - val_accuracy: 0.4850
# Epoch 25/100
# 105/105 [==============================] - 532s 5s/step - loss: 0.1199 - accuracy: 0.6355 - val_loss: 1.5494 - val_accuracy: 0.4812
# Epoch 26/100
# 105/105 [==============================] - 494s 5s/step - loss: 0.1196 - accuracy: 0.6346 - val_loss: 1.5431 - val_accuracy: 0.4825
# Epoch 27/100
#  96/105 [==========================>...] - ETA: 39s - loss: 0.1172 - accuracy: 0.6413

# %% [markdown]
# ## Translation after training

# %%
from transformers import pipeline

translator = pipeline('translation', model=model, tokenizer=tokenizer)

# %%
translator('Chcę złożyć wniosek o wydanie dowodu osobistego.')
# Out:
# [{'translation_text': 'Nowy dowód1 chcieć'}]

# %%
translator('Czy mogę odebrać dowód?')
# Out:
# [{'translation_text': 'Być mój nowy dowód1'}]

# %% [markdown]
# ## Model testing

# %%
model = TFAutoModelForSeq2SeqLM.from_pretrained("final_model/model")
tokenizer = AutoTokenizer.from_pretrained("final_model/tokenizer/")
# Out:
# All model checkpoint layers were used when initializing TFMarianMTModel.
#
# All the layers of TFMarianMTModel were initialized from the model checkpoint at final_model/model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFMarianMTModel for predictions without further training.

# %%
translator = pipeline('translation', model=model, tokenizer=tokenizer)
bleu = CustomBleu(data, translator)

# %%
bleu.data
# Out:
#                                                      pl  \
# 0     Mój dziadek jest inwalidą wojennym i otrzymuję...
# 1                   Czy ma Pan legitymację kombatancką?
# 2                     Mam wezwanie na komisje lekarską.
# 3                       Moja mama otrzymuje rentę krus.
# 4                  Czy ma Pani ukończony kurs rolniczy?
# ...                                                 ...
# 1206                            Zmieniłem(am) nazwisko.
# 1207                            Zmieniłem(am) nazwisko.
# 1208                            Zmieniłem(am) nazwisko.
# 1209                                        Mam 18 lat.
# 1210                                      Mam paszport.
#
#                                             mig
# 0     Mój dziadek inwalida wojna renta zus mieć
# 1                 Ty legitymacja kombatant mieć
# 2             Ja komisja lekarska wezwanie mieć
# 3                     Moja mama renta krus mieć
# 4                         Ty kurs rolniczy mieć
# ...                                         ...
# 1206                           Nazwisko zmiana2
# 1207                        Przeniesc inne spać
# 1208                                   Już ślub
# 1209                                 Już 18 lat
# 1210                              Paszport mieć
#
# [1211 rows x 2 columns]

# %%
score, df_ref = bleu.score(train_test_dataset)

# %%
print(f"BLEU score: {score}")
df_ref.head(10)
# Out:
# BLEU score: 0.30199641394191035
#                                            reference  \
# 0                        [[Ty, ranna], [Pan, ranna]]
# 1                    [Laryngolog, przyjmować, kiedy]
# 2        [[Ja, internet, mam], [Ja, internet, mieć]]
# 3  [[Podatek, rolny, leśny, płacić, trzeba], [Pod...
# 4                            [Ty, choroba, poważnie]
# 5         [[Pani, krewni, masz], [Ty, krewni, masz]]
# 6                       [Ty, emerytura, renta, mieć]
# 7  [[Pani, dowód, mieć], [Pani, dowód, masz], [Ty...
# 8  [[Ja, zmiana1, nazwisko], [Ja, zmiana2, nazwis...
# 9   [[Ty, gaśnica, mieć], [Ty, Pani, gaśnica, mieć]]
#
#                                  translation
# 0                                [Ty, ranna]
# 1            [Laryngolog, przyjmować, kiedy]
# 2                       [Ja, internet, mieć]
# 3  [Płacja, rzeszno, zrobna, płacić, musieć]
# 4                       [Ty, choroba, słabo]
# 5                         [Ty, krewni, masz]
# 6               [Ty, emerytura, renta, mieć]
# 7                        [Pani, dowód, mieć]
# 8                    [Przeniesc, inne, spać]
# 9                      [Pani, gaśnica, mieć]

# %% [markdown]
# ## Save final model

# %%
tokenizer.save_pretrained("final_model/tokenizer/")
model.save_pretrained("final_model/model")
# Out:
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 512, 'num_beams': 6, 'bad_words_ids': [[63429]], 'forced_eos_token_id': 0}
